# %% [markdown]
# # LOTUS - dataset overview
#
# [LOTUS initiative](https://lotus.nprod.net/) is a database of natural products connected to organisms. Befor expanding the database, we like to have an overview about the last LOTUS datasest.
#
# [latest LOTUS dataset (v10)](https://zenodo.org/records/7534071)
#
# More info in the [Paper (DOI:70780)](https://elifesciences.org/articles/70780)
#
#
# ## load dataset

# %%
# Example of loading LOTUS datasets with polars (python module)
import polars as pl
import numpy as np


df_lotus = pl.read_csv(
        "./data/230106_frozen_metadata.csv.gz",
        infer_schema_length=50000,
        null_values=["", "NA"],
        schema_overrides=
        {
            "structure_xlogp": pl.Float32,
            "structure_cid": pl.UInt32,
            "organism_taxonomy_ncbiid": pl.UInt32,
            "organism_taxonomy_ottid": pl.UInt32,
            "structure_stereocenters_total": pl.UInt32,
            "structure_stereocenters_unspecified": pl.UInt32,
        },
    )

df_lotus = df_lotus.with_columns(
        pl.col("organism_taxonomy_gbifid")
        .map_elements(lambda x: np.nan if x.startswith("c(") else x)
        .cast(pl.UInt32)
        .alias("organism_taxonomy_gbifid")
    )

print(f"all columns of LOTUS (total: {df_lotus.shape[1]}): \n{df_lotus.columns}")
# Out:
# all columns of LOTUS (total: 39):
# ['structure_wikidata', 'structure_inchikey', 'structure_inchi', 'structure_smiles', 'structure_molecular_formula', 'structure_exact_mass', 'structure_xlogp', 'structure_smiles_2D', 'structure_cid', 'structure_nameIupac', 'structure_nameTraditional', 'structure_stereocenters_total', 'structure_stereocenters_unspecified', 'structure_taxonomy_npclassifier_01pathway', 'structure_taxonomy_npclassifier_02superclass', 'structure_taxonomy_npclassifier_03class', 'structure_taxonomy_classyfire_chemontid', 'structure_taxonomy_classyfire_01kingdom', 'structure_taxonomy_classyfire_02superclass', 'structure_taxonomy_classyfire_03class', 'structure_taxonomy_classyfire_04directparent', 'organism_wikidata', 'organism_name', 'organism_taxonomy_gbifid', 'organism_taxonomy_ncbiid', 'organism_taxonomy_ottid', 'organism_taxonomy_01domain', 'organism_taxonomy_02kingdom', 'organism_taxonomy_03phylum', 'organism_taxonomy_04class', 'organism_taxonomy_05order', 'organism_taxonomy_06family', 'organism_taxonomy_07tribe', 'organism_taxonomy_08genus', 'organism_taxonomy_09species', 'organism_taxonomy_10varietas', 'reference_wikidata', 'reference_doi', 'manual_validation']
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.

# %% [markdown]
# The 39 columns are separated in **structure (=chemical structure)**,  **organism** and the **source**.
#
# For the pickaxe (MINEs) it is necessary to provide a SMILE and a ID.
# In this case would be used the coloumns **3D SMILES (structure_smiles)** and **structure_wikidata**.

# %%
# write in bold the specific title
print("\033[1m\nuniqueness over categories:\033[0m")

# unique counts only of the "chemical structure" columns
unique_counts = df_lotus.select(
    df_lotus.columns[0:20]
    ).n_unique()
print("all structure columns:", str(unique_counts))

# unique counts only of the "organism" columns []
unique_counts = df_lotus.select(
    df_lotus.columns[21:35]
    ).n_unique()
print("all organism columns:", str(unique_counts))

# unique counts for the full dataset
unique_counts = df_lotus.select(
    df_lotus.columns[:]
    ).n_unique()
print("all columns:", str(unique_counts))

# unique counts for the pickaxe/MINEs input
print("\033[1m\nImportant Info for pickaxe (MINEs):\033[0m")
print(f'rows for LOTUS dataset: {df_lotus.shape[0]}')
print(f'\nunique "structure_smiles": {df_lotus.select(["structure_smiles"]).n_unique()}')
print(f'unique "structure_wikidata": {df_lotus.select(["structure_wikidata"]).n_unique()}')
print(f'unique "structure_smiles" and "structure_wikidata": {df_lotus.select(["structure_smiles", "structure_wikidata"]).n_unique()}')
print(f'\nunique "structure_smiles": {df_lotus.select(["structure_smiles"]).n_unique()}')
print(f'unique "structure_inchi": {df_lotus.select(["structure_inchi"]).n_unique()}')
print(f'unique "structure_smiles" and "structure_inchi": {df_lotus.select(["structure_smiles", "structure_inchi"]).n_unique()}')
# Out:
# uniqueness over categories:
# all structure columns: 257226
# all organism columns: 36803
# all columns: 792364
#
# Important Info for pickaxe (MINEs):
# rows for LOTUS dataset: 792364
#
# unique "structure_smiles": 220820
# unique "structure_wikidata": 220783
# unique "structure_smiles" and "structure_wikidata": 220834
#
# unique "structure_smiles": 220820
# unique "structure_inchi": 220823
# unique "structure_smiles" and "structure_inchi": 220823

# %% [markdown]
# The uniqueness will be reduced from the full dataset (792'364 rows) to the pickaxe inputfile "structure_smiles" and "structure_wikidata" (220'834 rows), which is **27.9%** of the full dataset.
#
# This are good news, so the dataset will be reduced drasticaly.
#
# Which is a little unusual that we have more SMILES than wikidata links.
# This could be, because not all SMILES have a wikidata link yet, which in turn cannot be because LOTUS is ‘complete’ and has no empty fields.
#
# If we look at the inchi's, it is also a little bit surprising, that there should be 3 duplicates.

# %%
# change the configsetting, to see the full tables
pl.Config.set_tbl_rows(100)
pl.Config(fmt_str_lengths=550)


# make a dataframe with only the two columns: "structure_smiles" and "structure_wikidata"
df_lotus_for_pickaxe_with_wikidata = df_lotus.select(["structure_smiles", "structure_wikidata"]).unique()

# search for the duplicates and print them
df_lotus_for_pickaxe_with_wikidata_duplicates = df_lotus_for_pickaxe_with_wikidata.filter(df_lotus_for_pickaxe_with_wikidata.select(['structure_smiles']).is_duplicated()).sort('structure_smiles')
print(f'{df_lotus_for_pickaxe_with_wikidata_duplicates[0:2, :]}')


# make a dataframe with only the two columns: "structure_smiles" and "structure_inchi"
df_lotus_for_pickaxe_with_inchi = df_lotus.select(["structure_smiles", "structure_inchi"]).unique()

# search for the duplicates and print them
df_lotus_for_pickaxe_with_inchi_duplicates = df_lotus_for_pickaxe_with_inchi.filter(df_lotus_for_pickaxe_with_inchi.select(['structure_smiles']).is_duplicated()).sort('structure_smiles')
print(f'{df_lotus_for_pickaxe_with_inchi_duplicates[0:2, :]}')
# Out:
# shape: (2, 2)
# ┌───────────────────┬──────────────────────────────────────────┐
# │ structure_smiles  ┆ structure_wikidata                       │
# │ ---               ┆ ---                                      │
# │ str               ┆ str                                      │
# ╞═══════════════════╪══════════════════════════════════════════╡
# │ C1CCC2(CCCCO2)OC1 ┆ http://www.wikidata.org/entity/Q804105   │
# │ C1CCC2(CCCCO2)OC1 ┆ http://www.wikidata.org/entity/Q55620521 │
# └───────────────────┴──────────────────────────────────────────┘
# shape: (2, 2)
# ┌───────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────┐
# │ structure_smiles                                          ┆ structure_inchi                                          │
# │ ---                                                       ┆ ---                                                      │
# │ str                                                       ┆ str                                                      │
# ╞═══════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════╡
# │ CC1=C\C=C\C(C)=C\C[C@H](C)NC(=O)/C(CC(C)C)=C/C(C)=C/C=C/C ┆ InChI=1S/C46H71N3O8/c1-30(2)26-36-27-33(5)19-13-12-16-25 │
# │ =C/[C@@](C)(O)[C@@H](O[C@@H]2OC[C@@H](O[C@H]3C[C@@](C)(O) ┆ -45(8,52)38(22-15-14-18-31(3)20-17-21-32(4)23-24-34(6)48 │
# │ [C@H](N(C)C)[C@@H](C)O3)[C@H](O)[C@H]2N)/C=C\C=C\1        ┆ -43(36)51)57-44-40(47)41(50)37(29-54-44)56-39-28-46(9,53 │
# │                                                           ┆ )42(49(10)11)35(7)55-39/h12-23,25,27,30,34-35,37-42,44,5 │
# │                                                           ┆ 0,52-53H,24,26,28-29,47H2,1-11H3,(H,48,51)/b13-12+,18-14 │
# │                                                           ┆ +,21-17+,22-15-,25-16+,31-20+,32-23+,33-19+,36-27+/t34-, │
# │                                                           ┆ 35+,37+,38-,39-,40+,41-,42+,44-,45+,46+/m0/s1            │
# │ CC1=C\C=C\C(C)=C\C[C@H](C)NC(=O)/C(CC(C)C)=C/C(C)=C/C=C/C ┆ InChI=1S/C46H71N3O8/c1-30(2)26-36-27-33(5)19-13-12-16-25 │
# │ =C/[C@@](C)(O)[C@@H](O[C@@H]2OC[C@@H](O[C@H]3C[C@@](C)(O) ┆ -45(8,52)38(22-15-14-18-31(3)20-17-21-32(4)23-24-34(6)48 │
# │ [C@H](N(C)C)[C@@H](C)O3)[C@H](O)[C@H]2N)/C=C\C=C\1        ┆ -43(36)51)57-44-40(47)41(50)37(29-54-44)56-39-28-46(9,53 │
# │                                                           ┆ )42(49(10)11)35(7)55-39/h12-23,25,27,30,34-35,37-42,44,5 │
# │                                                           ┆ 0,52-53H,24,26,28-29,47H2,1-11H3,(H,48,51)/b13-12+,18-14 │
# │                                                           ┆ +,21-17+,22-15+,25-16+,31-20+,32-23+,33-19+,36-27+/t34-, │
# │                                                           ┆ 35+,37+,38-,39-,40+,41-,42+,44-,45+,46+/m0/s1            │
# └───────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────┘

# %% [markdown]
# The real reason is, that some SMILES have two wikidata entries, which is confusing. If we check the links, they are both linked to the "same" chemical component.
# This makes also sense, because the amount of this duplicated entries (28) correspond to the amount of entries of only SMILES (220820) plus the additinal entries (14).
#
# The same problem we can see with the INCHI's. In this case, we have multiple inchi's for the same SMILE's. This is possible, because the INCHI's describes the molecule more exactly then the SMILES.
#
# - Why do we have less wikidata links then SMILES? This is a lose of information, no?
# We can see below, that some wikidatalinks are pointing to multiple SMILE's. This can be the case, because the wikilinks sometimes are represanting chemical groupes, which can be different.

# %%
# make a dataframe with only the two columns: "structure_smiles" and "structure_wikidata"
df_lotus_for_pickaxe_with_wikidata = df_lotus.select(["structure_smiles", "structure_wikidata"]).unique()

# search for the duplicates and print them
df_lotus_for_pickaxe_with_wikidata_duplicates = df_lotus_for_pickaxe_with_wikidata.filter(df_lotus_for_pickaxe_with_wikidata.select(['structure_wikidata']).is_duplicated()).sort('structure_wikidata')
print(f'{df_lotus_for_pickaxe_with_wikidata_duplicates}')
# Out:
# shape: (102, 2)
# ┌──────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────┐
# │ structure_smiles                                                         ┆ structure_wikidata                        │
# │ ---                                                                      ┆ ---                                       │
# │ str                                                                      ┆ str                                       │
# ╞══════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════╡
# │ C/C=C1/CN2CC[C@]34c5ccccc5N5[C@H](C(=O)OC)[C@H]1C[C@H]2[C@@]53Oc1c4cc2c( ┆ http://www.wikidata.org/entity/Q105144092 │
# │ c1O)C(=O)O[C@@]13[C@@H]4C[C@H]5/C(=C\C)CN4CC[C@@]21c1ccccc1N3[C@@H]5C(=O ┆                                           │
# │ )OC                                                                      ┆                                           │
# │ C/C=C1/CN2CC[C@@]34c5ccccc5N5[C@H](C(=O)OC)[C@H]1C[C@H]2[C@]53Oc1c4cc2c( ┆ http://www.wikidata.org/entity/Q105144092 │
# │ c1O)C(=O)O[C@]13[C@@H]4C[C@H]5/C(=C\C)CN4CC[C@@]21c1ccccc1N3[C@@H]5C(=O) ┆                                           │
# │ OC                                                                       ┆                                           │
# │ C/C=C1/CN2CC[C@@]34c5ccccc5N5C(=O)C([C@H]6C[C@]78c9ccccc9N9C(=O)C=C[C@H] ┆ http://www.wikidata.org/entity/Q105362913 │
# │ ([C@H]97)[C@H]7C[C@@H]8N6C/C7=C/C)C=C([C@H]1C[C@H]23)[C@H]54             ┆                                           │
# │ C/C=C1/CN2[C@@H](C3=C[C@@H]4[C@@H]5N(C3=O)c3ccccc3[C@@]53CCN5C/C(=C/C)[C ┆ http://www.wikidata.org/entity/Q105362913 │
# │ @@H]4C[C@H]53)C[C@@]34c5ccccc5N5C(=O)CC=C([C@H]1C[C@H]23)[C@H]54         ┆                                           │
# │ O=C(CO)C(O)C(O)C(O)COP(=O)(O)O                                           ┆ http://www.wikidata.org/entity/Q110077781 │
# │ O=P(O)(O)OCC1OC(O)(CO)C(O)C1O                                            ┆ http://www.wikidata.org/entity/Q110077781 │
# │ CCCCCC=CC(=O)CCc1ccc(O)c(OC)c1                                           ┆ http://www.wikidata.org/entity/Q110184380 │
# │ CCCCC/C=C\C(=O)CCc1ccc(O)c(OC)c1                                         ┆ http://www.wikidata.org/entity/Q110184380 │
# │ CC(C)C12CCC(C)(CC1)O2                                                    ┆ http://www.wikidata.org/entity/Q12470088  │
# │ CC(C)[C@]12CC[C@](C)(CC1)O2                                              ┆ http://www.wikidata.org/entity/Q12470088  │
# │ CO[C@@H]1[C@@H](OC(=O)c2ccc(C)[nH]2)[C@@H](O)C(Oc2ccc3c(=O)c(NC(=O)c4c[n ┆ http://www.wikidata.org/entity/Q15408415  │
# │ H]c(C(=O)Nc5c(O)oc6c(C)c(OC7OC(C)(C)[C@H](OC)[C@@H](OC(=O)c8ccc(C)[nH]8) ┆                                           │
# │ [C@H]7O)ccc6c5=O)c4C)c(O)oc3c2C)OC1(C)C                                  ┆                                           │
# │ CO[C@@H]1[C@@H](OC(=O)c2ccc(C)[nH]2)[C@@H](O)[C@H](Oc2ccc3c(O)c(NC(=O)c4 ┆ http://www.wikidata.org/entity/Q15408415  │
# │ c[nH]c(C(=O)Nc5c(O)c6ccc(O[C@@H]7OC(C)(C)[C@H](OC)[C@@H](OC(=O)c8ccc(C)[ ┆                                           │
# │ nH]8)[C@H]7O)c(C)c6oc5=O)c4C)c(=O)oc3c2C)OC1(C)C                         ┆                                           │
# │ COC(=O)C1=C2Nc3ccccc3[C@@]23CCN2CCC[C@@](C(C)O)(C1)[C@H]23               ┆ http://www.wikidata.org/entity/Q15425824  │
# │ COC(=O)C1=C2Nc3ccccc3[C@@]23CCN2CCC[C@@]([C@@H](C)O)(C1)[C@H]23          ┆ http://www.wikidata.org/entity/Q15425824  │
# │ CC1=CCC2C3C(C(C)C)CC[C@]2(C)C13                                          ┆ http://www.wikidata.org/entity/Q22026403  │
# │ CC1=CC[C@H]2[C@H]3[C@@H](C(C)C)CC[C@]2(C)[C@H]13                         ┆ http://www.wikidata.org/entity/Q22026403  │
# │ C=CC1=CC(=O)[C@@H]2[C@H](CC[C@@H]3C(C)(C)[C@H](O)C[C@H](O)[C@@]23C)[C@@H ┆ http://www.wikidata.org/entity/Q23804989  │
# │ ]1C                                                                      ┆                                           │
# │ C=CC1=CC(=O)[C@H]2[C@@H](CC[C@H]3C(C)(C)[C@@H](O)C[C@@H](O)[C@]23C)[C@H] ┆ http://www.wikidata.org/entity/Q23804989  │
# │ 1C                                                                       ┆                                           │
# │ CC(=O)O[C@@H]1C[C@H]2O[C@@H]3C=C(C)CC[C@]3(C)[C@]1(C)[C@@]21CO1          ┆ http://www.wikidata.org/entity/Q256431    │
# │ CC(=O)O[C@@H]1C[C@H]2O[C@@H]3C=C(C)CC[C@]3(C)[C@]1(C)[C@]21CO1           ┆ http://www.wikidata.org/entity/Q256431    │
# │ COc1cc2c(cc1O)CCN[C@]21CS[C@@H]2c3c(OC(C)=O)c(C)c4c(c3[C@H](COC1=O)N1[C@ ┆ http://www.wikidata.org/entity/Q2637746   │
# │ @H]2[C@H]2c3c(cc(C)c(OC)c3O)C[C@@H]([C@@H]1O)N2C)OCO4                    ┆                                           │
# │ COc1cc2c(cc1O)CCN[C@@]21CS[C@@H]2c3c(OC(C)=O)c(C)c4c(c3[C@H](COC1=O)N1[C ┆ http://www.wikidata.org/entity/Q2637746   │
# │ @@H]2[C@H]2c3c(cc(C)c(OC)c3O)C[C@@H]([C@@H]1O)N2C)OCO4                   ┆                                           │
# │ C/C=C1/CN2[C@H]3Cc4c([nH]c5ccccc45)[C@@H]2C[C@H]1[C@@]3(C=O)C(=O)OC      ┆ http://www.wikidata.org/entity/Q27102100  │
# │ C/C=C1/CN2[C@H]3Cc4c([nH]c5ccccc45)[C@@H]2C[C@@H]1[C@@]3(C=O)C(=O)OC     ┆ http://www.wikidata.org/entity/Q27102100  │
# │ C=C1C(=O)O[C@H]2[C@H]1[C@H](OC(=O)[C@]1(C)O[C@@H]1C)[C@@H](OC(C)=O)/C(C( ┆ http://www.wikidata.org/entity/Q27106482  │
# │ =O)OC)=C\CC[C@@]1(C)O[C@H]21                                             ┆                                           │
# │ C=C1C(=O)O[C@H]2[C@@H]1[C@@H](OC(=O)[C@@]1(C)O[C@H]1C)[C@H](OC(C)=O)/C(C ┆ http://www.wikidata.org/entity/Q27106482  │
# │ (=O)OC)=C\CC[C@@]1(C)O[C@H]21                                            ┆                                           │
# │ CO[C@@H]1C=C[C@@]23c4cc5c(cc4CN(C[C@@H]2O)[C@H]3C1)OCO5                  ┆ http://www.wikidata.org/entity/Q27106819  │
# │ CO[C@@H]1C=C[C@@]23c4cc5c(cc4CN(C[C@H]2O)[C@H]3C1)OCO5                   ┆ http://www.wikidata.org/entity/Q27106819  │
# │ C=C1CC[C@]2(C)CC[C@]3(C)[C@H](CC[C@@H]4[C@@]5(C)CC[C@H](O)C(C)(C)[C@@H]5 ┆ http://www.wikidata.org/entity/Q27108380  │
# │ CC[C@]43C)[C@H]2[C@@H]1C                                                 ┆                                           │
# │ C=C1CC[C@]2(C)CC[C@]3(C)[C@H](CC[C@@H]4[C@@]5(C)CC[C@H](O)C(C)(C)[C@@H]5 ┆ http://www.wikidata.org/entity/Q27108380  │
# │ CC[C@]43C)[C@@H]2[C@@H]1C                                                ┆                                           │
# │ CO[C@H]1C[C@H](O[C@H]2CC[C@]3(C=O)[C@H]4CC[C@]5(C)[C@@H](C6=CC(=O)OC6)CC ┆ http://www.wikidata.org/entity/Q27108663  │
# │ [C@]5(O)[C@@H]4CC[C@]3(O)C2)O[C@H](C)[C@H]1O[C@@H]1O[C@H](CO)[C@@H](O[C@ ┆                                           │
# │ @H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)[C@H](O)[C@H]1O                   ┆                                           │
# │ CO[C@H]1C[C@H](O[C@H]2CC[C@]3(C=O)[C@H]4CC[C@]5(C)[C@@H](C6=CC(=O)OC6)CC ┆ http://www.wikidata.org/entity/Q27108663  │
# │ [C@]5(O)[C@@H]4CC[C@]3(O)C2)O[C@H](C)[C@H]1O[C@@H]1O[C@H](CO[C@@H]2O[C@H ┆                                           │
# │ ](CO)[C@@H](O)[C@H](O)[C@H]2O)[C@@H](O)[C@H](O)[C@H]1O                   ┆                                           │
# │ CC[C@H](C)[C@H]1O[C@]2(C=C[C@@H]1C)C[C@@H]1C[C@@H](C/C=C(\C)[C@@H](O[C@H ┆ http://www.wikidata.org/entity/Q27110116  │
# │ ]3C[C@H](OC)[C@@H](O[C@H]4C[C@H](OC)[C@@H](O)[C@H](C)O4)[C@H](C)O3)[C@@H ┆                                           │
# │ ](C)/C=C/C=C3\CO[C@@H]4[C@H](OC)C(C)=C[C@@H](C(=O)O1)[C@]34O)O2          ┆                                           │
# │ CCC(C)[C@H]1O[C@]2(C=C[C@@H]1C)C[C@@H]1C[C@@H](C/C=C(\C)[C@@H](O[C@H]3C[ ┆ http://www.wikidata.org/entity/Q27110116  │
# │ C@H](OC)[C@@H](O[C@H]4C[C@H](OC)[C@@H](O)[C@H](C)O4)[C@H](C)O3)[C@@H](C) ┆                                           │
# │ /C=C/C=C3\CO[C@@H]4[C@H](OC)C(C)=C[C@@H](C(=O)O1)[C@]34O)O2              ┆                                           │
# │ CO[C@H]1[C@@H](O)[C@H](O)[C@H](OC[C@@]23C[C@@H]4[C@H](C)CC[C@H]4[C@@]4(C ┆ http://www.wikidata.org/entity/Q27123493  │
# │ =O)C[C@H]2C=C(C(C)C)[C@@]34C(=O)O)O[C@@H]1C                              ┆                                           │
# │ CO[C@H]1[C@@H](O)[C@H](O)[C@H](OC[C@@]23C[C@@H]4[C@H](C)CC[C@H]4[C@@]4(C ┆ http://www.wikidata.org/entity/Q27123493  │
# │ =O)C[C@@H]2C=C(C(C)C)[C@@]34C(=O)O)O[C@@H]1C                             ┆                                           │
# │ C/C=C(\C)C(=O)OC[C@]1(O)[C@H]2C[C@H]2[C@]2(C)[C@@H]3CC4=C5[C@H](/C(=C(\C ┆ http://www.wikidata.org/entity/Q27138126  │
# │ )C(=O)OC)C(=O)[C@H](O)[C@@]5(C)[C@@H]5C[C@H]45)[C@@]34OC(=O)C(CO)=C4C[C@ ┆                                           │
# │ @H]12                                                                    ┆                                           │
# │ COC(=O)/C=C(\C)C[C@]1(O)[C@H]2CC3=C(CO)C(=O)O[C@@]34[C@@H]3C5=C(C[C@H]4[ ┆ http://www.wikidata.org/entity/Q27138126  │
# │ C@@]2(C)[C@@H]2C[C@@H]21)[C@H]1C[C@H]1[C@]5(C)[C@@H](O)C(=O)/C3=C(/C)C(= ┆                                           │
# │ O)OC                                                                     ┆                                           │
# │ C=CC1=CC(=O)[C@@H]2[C@H](CC[C@@H]3C(C)(C)[C@H](O)[C@H](O)[C@H](O)[C@@]23 ┆ http://www.wikidata.org/entity/Q27140060  │
# │ C)[C@@H]1C                                                               ┆                                           │
# │ C=CC1=CC(=O)[C@H]2[C@@H](CC[C@H]3C(C)(C)[C@@H](O)[C@@H](O)[C@@H](O)[C@]2 ┆ http://www.wikidata.org/entity/Q27140060  │
# │ 3C)[C@H]1C                                                               ┆                                           │
# │ CC[C@H](C)[C@H]1C(=O)OC2c3cc(C)cc(O)c3C3=C(C(=O)c4c(O)cccc4C3=O)N21      ┆ http://www.wikidata.org/entity/Q27155645  │
# │ CC[C@H](C)[C@H]1C(=O)O[C@H]2c3cc(C)cc(O)c3C3=C(C(=O)c4c(O)cccc4C3=O)N12  ┆ http://www.wikidata.org/entity/Q27155645  │
# │ C[C@H](CC[C@@H](O)[C@@H](O)[C@@H](O)CO)[C@H]1CC[C@]2(C)[C@H]3CC[C@@H]4[C ┆ http://www.wikidata.org/entity/Q27225584  │
# │ @@]5(C)CCCC(C)(C)[C@@H]5CC[C@@]4(C)[C@]3(C)CC[C@@H]12                    ┆                                           │
# │ CC(CC[C@@H](O)[C@@H](O)[C@@H](O)CO)[C@H]1CC[C@@]2(C)C1CC[C@]1(C)C2CCC2[C ┆ http://www.wikidata.org/entity/Q27225584  │
# │ @@]3(C)CCCC(C)(C)C3CC[C@]21C                                             ┆                                           │
# │ CCN1C[C@]2(COC)[C@H](O)C[C@H](OC)[C@@]34[C@@H]5C[C@@]6(O)[C@H](OC(=O)c7c ┆ http://www.wikidata.org/entity/Q27256545  │
# │ cccc7)[C@@H]5[C@@](O)([C@@H]([C@H](OC)[C@H]23)[C@@H]14)[C@@H](O)[C@@H]6O ┆                                           │
# │ C                                                                        ┆                                           │
# │ CCN1C[C@]2(COC)[C@H](O)C[C@H](OC)[C@]34C1[C@H]([C@H](OC)[C@H]23)[C@]1(O) ┆ http://www.wikidata.org/entity/Q27256545  │
# │ [C@H]2[C@@H](OC(=O)c3ccccc3)[C@](O)(C[C@H]24)[C@@H](OC)[C@@H]1O          ┆                                           │
# │ CO[C@@H](C)[C@H]1C[C@H](C)[C@H]([C@@H](C)/C=C/[C@@H]2CC[C@@H](C)[C@H](/C ┆ http://www.wikidata.org/entity/Q27274977  │
# │ (=C/[C@H]3CCC[C@@H](C)[C@@H]3[C@H](C)C(=O)C3=C(O)COC3=O)CO)O2)O1         ┆                                           │
# │ CO[C@@H](C)[C@H]1C[C@H](C)[C@H]([C@@H](C)/C=C/[C@@H]2CC[C@@H](C)[C@H](/C ┆ http://www.wikidata.org/entity/Q27274977  │
# │ (=C/[C@H]3CCC[C@@H](C)[C@@H]3[C@H](C)/C(O)=C3/C(=O)COC3=O)CO)O2)O1       ┆                                           │
# │ CCN1C[C@]2(COC)[C@H](O)C[C@H](OC)[C@@]34[C@@H]5C[C@@]6(O)[C@H](O)[C@@H]5 ┆ http://www.wikidata.org/entity/Q27279200  │
# │ [C@@](O)([C@@H]([C@H](OC)[C@H]23)[C@@H]14)[C@@H](O)[C@@H]6OC             ┆                                           │
# │ CCN1C[C@]2(COC)[C@H](O)C[C@H](OC)[C@]34C1[C@H]([C@H](OC)[C@H]23)[C@]1(O) ┆ http://www.wikidata.org/entity/Q27279200  │
# │ [C@H]2[C@@H](O)[C@](O)(C[C@H]24)[C@@H](OC)[C@@H]1O                       ┆                                           │
# │ …                                                                        ┆ …                                         │
# │ N=c1nc(O)c2c([nH]1)NC[C@@H]1C[N+](c3ccc(C(=O)N[C@@H](CCC(=O)O)C(=O)[O-]) ┆ http://www.wikidata.org/entity/Q2823228   │
# │ cc3)=CN21                                                                ┆                                           │
# │ N=c1nc(O)c2c([nH]1)NC[C@@H]1C[N+](c3ccc(C(=O)N[C@@H](CCC(=O)O)C(=O)O)cc3 ┆ http://www.wikidata.org/entity/Q2823228   │
# │ )=CN21                                                                   ┆                                           │
# │ C[C@@H]1CC[C@@]2(OC1)O[C@H]1[C@@H](O)[C@H]3[C@@H]4CC[C@H]5C[C@@H](O[C@@H ┆ http://www.wikidata.org/entity/Q410968    │
# │ ]6O[C@H](CO)[C@H](O[C@@H]7O[C@H](CO)[C@@H](O)[C@H](O[C@@H]8OC[C@@H](O)[C ┆                                           │
# │ @H](O)[C@H]8O)[C@H]7O[C@@H]7O[C@H](CO)[C@@H](O)[C@H](O[C@@H]8O[C@H](CO)[ ┆                                           │
# │ C@@H](O)[C@H](O)[C@H]8O)[C@H]7O)[C@H](O)[C@H]6O)[C@H](O)C[C@]5(C)[C@H]4C ┆                                           │
# │ C[C@]3(C)[C@H]1[C@@H]2C                                                  ┆                                           │
# │ C[C@@H]1CC[C@@]2(OC1)O[C@H]1[C@@H](O)[C@H]3[C@@H]4CC[C@H]5C[C@@H](O[C@@H ┆ http://www.wikidata.org/entity/Q410968    │
# │ ]6O[C@H](CO)[C@H](O[C@@H]7O[C@H](CO)[C@@H](O)[C@H](O[C@@H]8OC[C@@H](O)[C ┆                                           │
# │ @H](O)[C@H]8O)[C@H]7O[C@@H]7O[C@H](CO)[C@H](O)[C@H](O[C@@H]8O[C@H](CO)[C ┆                                           │
# │ @@H](O)[C@H](O)[C@H]8O)[C@H]7O)[C@H](O)[C@H]6O)[C@H](O)C[C@]5(C)[C@H]4CC ┆                                           │
# │ [C@]3(C)[C@H]1[C@@H]2C                                                   ┆                                           │
# │ O=S(=O)(O)O/N=C(/CCc1ccccc1)S[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1O   ┆ http://www.wikidata.org/entity/Q412097    │
# │ O=S(=O)(O)O/N=C(\CCc1ccccc1)S[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1O   ┆ http://www.wikidata.org/entity/Q412097    │
# │ CN[C@H]1C[C@@H](N)[C@H](O)[C@@H](O[C@@H]2O[C@H](CO)[C@H](O)[C@@H]3OC4(O[ ┆ http://www.wikidata.org/entity/Q418735    │
# │ C@H]23)O[C@H]([C@@H](N)CO)[C@H](O)[C@@H](O)[C@H]4O)[C@@H]1O              ┆                                           │
# │ CN[C@H]1C[C@@H](N)[C@H](O)[C@@H](O[C@@H]2O[C@H](CO)[C@H](O)[C@@H]3O[C@]4 ┆ http://www.wikidata.org/entity/Q418735    │
# │ (O[C@H]23)O[C@H](C(N)CO)[C@H](O)[C@H](O)[C@H]4O)[C@@H]1O                 ┆                                           │
# │ O=C(O)C1=CC(=CC=[N+]2c3cc([O-])c(O[C@@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@H ┆ http://www.wikidata.org/entity/Q420138    │
# │ ]4O)cc3C[C@H]2C(=O)O)C[C@@H](C(=O)O)N1                                   ┆                                           │
# │ O=C(O)C1=N[C@H](C(=O)O)CC(/C=C/N2c3cc(O)c(O[C@@H]4O[C@H](CO)[C@@H](O)[C@ ┆ http://www.wikidata.org/entity/Q420138    │
# │ H](O)[C@H]4O)cc3C[C@H]2C(=O)O)=C1                                        ┆                                           │
# │ C/C(=C/C=C/[C@@H](C)C(=O)O)[C@H]1CN[C@H](C(=O)O)[C@H]1CC(=O)O            ┆ http://www.wikidata.org/entity/Q424386    │
# │ C/C(=C\C=C\[C@H](C)C(=O)O)[C@H]1CN[C@H](C(=O)O)[C@H]1CC(=O)O             ┆ http://www.wikidata.org/entity/Q424386    │
# │ Oc1ccc2c3c1O[C@H]1[C@@H](O)C=C[C@H]4[C@@H](C2)NCC[C@@]341                ┆ http://www.wikidata.org/entity/Q4327449   │
# │ Oc1ccc2c3c1OC1C(O)C=CC4C(C2)NCCC341                                      ┆ http://www.wikidata.org/entity/Q4327449   │
# │ CC(=O)N[C@@H](CS)C(=O)N[C@H]1[C@@H](OC2[C@H](O)[C@H](O)C(O)[C@H](O)[C@H] ┆ http://www.wikidata.org/entity/Q4382082   │
# │ 2O)O[C@H](CO)[C@@H](O)[C@@H]1O                                           ┆                                           │
# │ CC(=O)N[C@@H](CS)C(=O)N[C@H]1[C@@H](O[C@@H]2[C@H](O)[C@H](O)[C@@H](O)[C@ ┆ http://www.wikidata.org/entity/Q4382082   │
# │ H](O)[C@H]2O)O[C@H](CO)[C@@H](O)[C@@H]1O                                 ┆                                           │
# │ Cc1oc2nc1-c1nc(co1)-c1nc(co1)-c1nc(co1)-c1nc(co1)-c1nc(co1)C1=NC(CS1)c1n ┆ http://www.wikidata.org/entity/Q4391972   │
# │ c-2c(C)o1                                                                ┆                                           │
# │ Cc1oc2nc1-c1nc(co1)-c1nc(co1)-c1nc(co1)-c1nc(co1)-c1nc(co1)C1=N[C@@H](CS ┆ http://www.wikidata.org/entity/Q4391972   │
# │ 1)c1nc-2c(C)o1                                                           ┆                                           │
# │ CN1C2C[C@H](OC(=O)[C@@H](CO)c3ccccc3)CC1[C@@H](O)C2                      ┆ http://www.wikidata.org/entity/Q4765340   │
# │ CN1[C@@H]2C[C@H](OC(=O)[C@H](CO)c3ccccc3)C[C@H]1[C@@H](O)C2              ┆ http://www.wikidata.org/entity/Q4765340   │
# │ Cc1ccc2c(c1O)NC(O)C1CC(/C=C/C(N)=O)=CN1C2=O                              ┆ http://www.wikidata.org/entity/Q4773852   │
# │ Cc1ccc2c(c1O)N[C@@H](O)[C@@H]1CC(/C=C/C(N)=O)=CN1C2=O                    ┆ http://www.wikidata.org/entity/Q4773852   │
# │ CC(C)C[C@@H]1NC2N(C1=O)c1ccccc1C2(O)C[C@@H]1NC(=O)c2ccccc2-n2c1nc1ccccc1 ┆ http://www.wikidata.org/entity/Q4807912   │
# │ c2=O                                                                     ┆                                           │
# │ CC(C)C[C@@H]1N[C@H]2N(C1=O)c1ccccc1[C@@]2(O)C[C@@H]1NC(=O)c2ccccc2-n2c1n ┆ http://www.wikidata.org/entity/Q4807912   │
# │ c1ccccc1c2=O                                                             ┆                                           │
# │ CCC1CC2CN3CCc4c([nH]c5ccc(OC)cc45)C(C(=O)OC)(C2)C13                      ┆ http://www.wikidata.org/entity/Q5015902   │
# │ CC[C@H]1C[C@@H]2CN3CCc4c([nH]c5ccc(OC)cc45)[C@](C(=O)OC)(C2)[C@H]13      ┆ http://www.wikidata.org/entity/Q5015902   │
# │ O=C(O)C[C@H]1C(=O)O[C@H]2[C@H](OC(=O)c3cc(O)c(O)c(O)c3)[C@@H](OC(=O)c3cc ┆ http://www.wikidata.org/entity/Q5089010   │
# │ (O)c(O)c4c3[C@H]1[C@H](O)C(=O)O4)[C@H](OC(=O)c1cc(O)c(O)c(O)c1)O[C@@H]2C ┆                                           │
# │ OC(=O)c1cc(O)c(O)c(O)c1                                                  ┆                                           │
# │ O=C(O)C[C@@H]1C(=O)O[C@H]2[C@H](OC(=O)c3cc(O)c(O)c(O)c3)[C@@H](OC(=O)c3c ┆ http://www.wikidata.org/entity/Q5089010   │
# │ c(O)c(O)c4c3[C@H]1[C@H](O)C(=O)O4)[C@H](OC(=O)c1cc(O)c(O)c(O)c1)O[C@@H]2 ┆                                           │
# │ COC(=O)c1cc(O)c(O)c(O)c1                                                 ┆                                           │
# │ CC[C@H]1C[C@H]2CN3CCc4c([nH]c5ccccc45)[C@](C(=O)OC)(C2)[C@H]13           ┆ http://www.wikidata.org/entity/Q5172181   │
# │ CC[C@H]1C[C@@H]2CN3CCc4c([nH]c5ccccc45)[C@](C(=O)OC)(C2)[C@H]13          ┆ http://www.wikidata.org/entity/Q5172181   │
# │ CCC1NC(=O)C2C(Cl)C(Cl)CN2C(=O)C(CO)NC(=O)CC(c2ccccc2)NC(=O)C(CO)NC1=O    ┆ http://www.wikidata.org/entity/Q5198686   │
# │ CC[C@@H]1NC(=O)[C@@H]2[C@H](Cl)[C@H](Cl)CN2C(=O)[C@H](CO)NC(=O)C[C@H](c2 ┆ http://www.wikidata.org/entity/Q5198686   │
# │ ccccc2)NC(=O)[C@H](CO)NC1=O                                              ┆                                           │
# │ C[S+]([O-])CCCC/C(=N\OS(=O)(=O)O)S[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H ┆ http://www.wikidata.org/entity/Q5572329   │
# │ ]1O                                                                      ┆                                           │
# │ C[S+]([O-])CCCC/C(=N/OS(=O)(=O)O)S[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H ┆ http://www.wikidata.org/entity/Q5572329   │
# │ ]1O                                                                      ┆                                           │
# │ CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)[C@@H](O[C@@H]2O[C@H](C)[C@@H](O[C@H]3C[ ┆ http://www.wikidata.org/entity/Q6725209   │
# │ C@@](C)(O)[C@@H](O)[C@H](C)O3)[C@H](N(C)C)[C@H]2O)[C@@H](CC=O)C[C@@H](C) ┆                                           │
# │ C(=O)/C=C/C(C)=C/[C@@H]1CO[C@@H]1O[C@H](C)[C@@H](O)[C@@H](O)[C@H]1OC     ┆                                           │
# │ CC[C@H]1OC(=O)C[C@@H](O)[C@H](C)C(O[C@@H]2O[C@H](C)[C@@H](O[C@H]3C[C@@]( ┆ http://www.wikidata.org/entity/Q6725209   │
# │ C)(O)[C@@H](O)[C@H](C)O3)[C@H](N(C)C)[C@H]2O)[C@@H](CC=O)C[C@@H](C)C(=O) ┆                                           │
# │ /C=C/C(C)=C/C1CO[C@@H]1O[C@H](C)[C@@H](O)[C@@H](O)[C@H]1OC               ┆                                           │
# │ C[C@@H]1CC[C@@]2(OC1)O[C@H]1C[C@H]3[C@@H]4CC=C5C[C@@H](O[C@@H]6O[C@H](CO ┆ http://www.wikidata.org/entity/Q72501573  │
# │ )[C@@H](O)[C@H](O)[C@H]6O[C@@H]6O[C@@H](C)[C@H](O)[C@@H](O)[C@H]6O)CC[C@ ┆                                           │
# │ ]5(C)[C@H]4CC[C@]3(C)[C@@]1(O)[C@@H]2C                                   ┆                                           │
# │ C[C@@H]1CC[C@@]2(OC1)O[C@H]1C[C@H]3[C@@H]4CC=C5CC(O[C@@H]6O[C@H](CO)[C@@ ┆ http://www.wikidata.org/entity/Q72501573  │
# │ H](O)[C@H](O)[C@H]6O[C@@H]6C[C@@H](C)[C@H](O)[C@@H](O)[C@H]6O)CC[C@]5(C) ┆                                           │
# │ [C@H]4CC[C@]3(C)[C@@]1(O)[C@@H]2C                                        ┆                                           │
# │ CC(C)=CCC1=C(O)c2ccccc2C(=O)C1=O                                         ┆ http://www.wikidata.org/entity/Q739601    │
# │ CC(C)=CCC1=C(O)C(=O)c2ccccc2C1=O                                         ┆ http://www.wikidata.org/entity/Q739601    │
# │ CCC(C)c1nc2c(CCCNC(=N)N)nc(-c3c[nH]c4ccccc34)cn2c1O                      ┆ http://www.wikidata.org/entity/Q7915670   │
# │ CC[C@H](C)c1nc2c(CCCNC(=N)N)[nH]c(-c3c[nH]c4ccccc34)cn-2c1=O             ┆ http://www.wikidata.org/entity/Q7915670   │
# │ C=C[C@@]12COC(=O)C(=C)[C@@H]1[C@H]1OC(=O)C(=C)[C@@H]1[C@@H](O)C2         ┆ http://www.wikidata.org/entity/Q7922030   │
# │ C=C[C@]12COC(=O)C(=C)[C@@H]1[C@H]1OC(=O)C(=C)[C@@H]1[C@@H](O)C2          ┆ http://www.wikidata.org/entity/Q7922030   │
# │ C=C1NC(=O)[C@@H]2CS[C@@H](C)[C@H](NC(=O)[C@@H](CC(C)C)NC(=O)[C@@H]3CCCN3 ┆ http://www.wikidata.org/entity/Q83118994  │
# │ C(=O)CNC(=O)[C@@H](Cc3ccccc3)NC1=O)C(=O)N[C@@H](Cc1c[nH]c3ccccc13)C(=O)N ┆                                           │
# │ [C@H](CO)C(=O)N[C@@H]1CSC[C@@H](NC(=O)[C@H](CCC(N)=O)NC(=O)[C@H](C(C)C)N ┆                                           │
# │ C(=O)[C@H](N)CS[C@@H](C)[C@@H](C(=O)N[C@H](CCCCN)C(=O)O)NC(=O)[C@@H](CC( ┆                                           │
# │ N)=O)NC(=O)CNC(=O)[C@H](CC(=O)O)NC1=O)C(=O)N2                            ┆                                           │
# │ C=C1NC(=O)[C@@H]2CSCC[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@@H]3CCCN3C(=O)CN ┆ http://www.wikidata.org/entity/Q83118994  │
# │ C(=O)[C@H](Cc3ccccc3)NC1=O)C(=O)N[C@@H](Cc1c[nH]c3ccccc13)C(=O)N[C@@H](C ┆                                           │
# │ O)C(=O)N[C@H]1CSC[C@@H](NC(=O)[C@H](CCC(N)=O)NC(=O)[C@H](C(C)C)NC(=O)[C@ ┆                                           │
# │ @H](N)CSCC[C@H](C(=O)N[C@@H](CCCCN)C(=O)O)NC(=O)[C@H](CC(N)=O)NC(=O)CNC( ┆                                           │
# │ =O)[C@H](CC(=O)O)NC1=O)C(=O)N2                                           ┆                                           │
# │ CCCC(=O)C1=C(O)C(Cc2c(OC)cc(O)c(C(=O)CCC)c2O)=C(O)C(C)(C)C1=O            ┆ http://www.wikidata.org/entity/Q904668    │
# │ CCCC(=O)C1=C(O)C(C)(C)C(O)=C(Cc2c(OC)cc(O)c(C(=O)CCC)c2O)C1=O            ┆ http://www.wikidata.org/entity/Q904668    │
# │ CC/C=C/[C@@H]1C=CCC=CC1                                                  ┆ http://www.wikidata.org/entity/Q988591    │
# │ CC/C=C\[C@@H]1C=CCC=CC1                                                  ┆ http://www.wikidata.org/entity/Q988591    │
# └──────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────┘
