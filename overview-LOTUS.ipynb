# %% [markdown]
# # LOTUS - dataset overview
#
# [LOTUS initiative](https://lotus.nprod.net/) is a database of natural products connected to organisms. Befor expanding the database, we like to have an overview about the last LOTUS datasest.
#
# [latest LOTUS dataset (v10)](https://zenodo.org/records/7534071)
#
# More info in the [Paper (DOI:70780)](https://elifesciences.org/articles/70780)
#
#
# ## load dataset

# %%
# Example of loading LOTUS datasets with polars (python module)
import polars as pl
import numpy as np

  
df_lotus = pl.read_csv(
        "./data/230106_frozen_metadata.csv.gz",
        dtypes={
            "structure_xlogp": pl.Float32,
            "structure_cid": pl.UInt32,
            "organism_taxonomy_ncbiid": pl.UInt32,
            "organism_taxonomy_ottid": pl.UInt32,
            "structure_stereocenters_total": pl.UInt32,
            "structure_stereocenters_unspecified": pl.UInt32,
        },
        infer_schema_length=50000,
        null_values=["", "NA"],
    )

df_lotus = lotus.with_columns(
        pl.col("organism_taxonomy_gbifid")
        .map_elements(lambda x: np.nan if x.startswith("c(") else x)
        .cast(pl.UInt32)
        .alias("organism_taxonomy_gbifid")
    )

print("all columns of LOTUS: ", df_lotus.columns)
# Out:
# /tmp/ipykernel_31659/3565593164.py:6: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   df_lotus = pl.read_csv(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       2 import polars as pl
#       3 import numpy as np
# ----> 6 df_lotus = pl.read_csv(
#       7         "./data/230106_frozen_metadata.csv.gz",
#       8         dtypes={
#       9             "structure_xlogp": pl.Float32,
#      10             "structure_cid": pl.UInt32,
#      11             "organism_taxonomy_ncbiid": pl.UInt32,
#      12             "organism_taxonomy_ottid": pl.UInt32,
#      13             "structure_stereocenters_total": pl.UInt32,
#      14             "structure_stereocenters_unspecified": pl.UInt32,
#      15         },
#      16         infer_schema_length=50000,
#      17         null_values=["", "NA"],
#      18     )
#      20 df_lotus = lotus.with_columns(
#      21         pl.col("organism_taxonomy_gbifid")
#      22         .map_elements(lambda x: np.nan if x.startswith("c(") else x)
#      23         .cast(pl.UInt32)
#      24         .alias("organism_taxonomy_gbifid")
#      25     )
#      27 print("all columns of LOTUS: ", df_lotus.columns)
#
# File ~/2024_GitHub_Master_Bioinformatics/lotus-dataset-statistics/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File ~/2024_GitHub_Master_Bioinformatics/lotus-dataset-statistics/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper at line 135 (1 times)]
#
# File ~/2024_GitHub_Master_Bioinformatics/lotus-dataset-statistics/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:135, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     130 @wraps(function)
#     131 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     132     _rename_keyword_argument(
#     133         old_name, new_name, kwargs, function.__name__, version
#     134     )
# --> 135     return function(*args, **kwargs)
#
# File ~/2024_GitHub_Master_Bioinformatics/lotus-dataset-statistics/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:422, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     410         schema_overrides = {
#     411             new_to_current.get(column_name, column_name): column_dtype
#     412             for column_name, column_dtype in schema_overrides.items()
#     413         }
#     415 with prepare_file_arg(
#     416     source,
#     417     encoding=encoding,
#    (...)
#     420     storage_options=storage_options,
#     421 ) as data:
# --> 422     df = _read_csv_impl(
#     423         data,
#     424         has_header=has_header,
#     425         columns=columns if columns else projection,
#     426         separator=separator,
#     427         comment_prefix=comment_prefix,
#     428         quote_char=quote_char,
#     429         skip_rows=skip_rows,
#     430         schema_overrides=schema_overrides,
#     431         schema=schema,
#     432         null_values=null_values,
#     433         missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     434         ignore_errors=ignore_errors,
#     435         try_parse_dates=try_parse_dates,
#     436         n_threads=n_threads,
#     437         infer_schema_length=infer_schema_length,
#     438         batch_size=batch_size,
#     439         n_rows=n_rows,
#     440         encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     441         low_memory=low_memory,
#     442         rechunk=rechunk,
#     443         skip_rows_after_header=skip_rows_after_header,
#     444         row_index_name=row_index_name,
#     445         row_index_offset=row_index_offset,
#     446         sample_size=sample_size,
#     447         eol_char=eol_char,
#     448         raise_if_empty=raise_if_empty,
#     449         truncate_ragged_lines=truncate_ragged_lines,
#     450         decimal_comma=decimal_comma,
#     451         glob=glob,
#     452     )
#     454 if new_columns:
#     455     return _update_columns(df, new_columns)
#
# File ~/2024_GitHub_Master_Bioinformatics/lotus-dataset-statistics/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:568, in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     564         raise ValueError(msg)
#     566 projection, columns = parse_columns_arg(columns)
# --> 568 pydf = PyDataFrame.read_csv(
#     569     source,
#     570     infer_schema_length,
#     571     batch_size,
#     572     has_header,
#     573     ignore_errors,
#     574     n_rows,
#     575     skip_rows,
#     576     projection,
#     577     separator,
#     578     rechunk,
#     579     columns,
#     580     encoding,
#     581     n_threads,
#     582     path,
#     583     dtype_list,
#     584     dtype_slice,
#     585     low_memory,
#     586     comment_prefix,
#     587     quote_char,
#     588     processed_null_values,
#     589     missing_utf8_is_empty_string,
#     590     try_parse_dates,
#     591     skip_rows_after_header,
#     592     parse_row_index_args(row_index_name, row_index_offset),
#     593     sample_size=sample_size,
#     594     eol_char=eol_char,
#     595     raise_if_empty=raise_if_empty,
#     596     truncate_ragged_lines=truncate_ragged_lines,
#     597     decimal_comma=decimal_comma,
#     598     schema=schema,
#     599 )
#     600 return wrap_df(pydf)
#
# FileNotFoundError: No such file or directory (os error 2): ./data/230106_frozen_metadata.csv.gz
